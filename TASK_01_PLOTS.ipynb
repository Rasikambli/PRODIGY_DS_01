# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import  warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("C:\\Users\\RASIKA KAMBLI\\Downloads\\archive (17)\\Car_sales.csv")

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
data.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Vehicle_type            0
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Sales_in_thousands     0
# __year_resale_value    0
# Vehicle_type           0
# Price_in_thousands     0
# Engine_size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb_weight            0
# Fuel_capacity          0
# Fuel_efficiency        0
# Latest_Launch          0
# Power_perf_factor      0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 0 to 149
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         117 non-null    object
#  1   Model                117 non-null    object
#  2   Sales_in_thousands   117 non-null    float64
#  3   __year_resale_value  117 non-null    float64
#  4   Vehicle_type         117 non-null    object
#  5   Price_in_thousands   117 non-null    float64
#  6   Engine_size          117 non-null    float64
#  7   Horsepower           117 non-null    float64
#  8   Wheelbase            117 non-null    float64
#  9   Width                117 non-null    float64
#  10  Length               117 non-null    float64
#  11  Curb_weight          117 non-null    float64
#  12  Fuel_capacity        117 non-null    float64
#  13  Fuel_efficiency      117 non-null    float64
#  14  Latest_Launch        117 non-null    object
# ...

# %%
plt.figure(figsize=(20,5))

plt.subplot(1,3,1)
plt.title('Sales_in_thousands')
data['Sales_in_thousands'].hist(bins=15,edgecolor='Black',alpha=0.5,color='Red')
plt.subplot(1,3,2)
plt.title('__year_resale_value')
data['__year_resale_value'].hist(bins=15,edgecolor='Black',alpha=0.5,color='Pink')
plt.subplot(1,3,3)
plt.title('Horsepower')
data['Horsepower'].hist(bins=15,edgecolor='Black',alpha=0.5,color='Purple')

plt.figure(figsize=(20,10))
plt.subplot(2,3,1)
plt.title('Engine_size')
data['Engine_size'].hist(bins=15,edgecolor='Black',alpha=0.5,color='Green')
plt.subplot(2,3,2)
plt.title('Fuel_capacity')
data['Fuel_capacity'].hist(bins=15,edgecolor='Black',alpha=0.5,color='Orange')
plt.subplot(2,3,3)
plt.title('Fuel_efficiency')
data['Fuel_efficiency'].hist(bins=15,edgecolor='Black',alpha=0.5,color='brown')
# Out:
# <AxesSubplot:title={'center':'Fuel_efficiency'}>

# %%
sns.set(rc={'figure.figsize':(25,8)})
sns.barplot(data['Manufacturer'],data['Sales_in_thousands'])
# Out:
# <AxesSubplot:xlabel='Manufacturer', ylabel='Sales_in_thousands'>

# %%
sns.set(rc={'figure.figsize':(25,8)})
sns.barplot(data['Manufacturer'],data['Fuel_capacity'])
# Out:
# <AxesSubplot:xlabel='Manufacturer', ylabel='Fuel_capacity'>

# %%
sns.set(rc={'figure.figsize':(25,8)})
sns.barplot(data['Manufacturer'],data['Engine_size'])
# Out:
# <AxesSubplot:xlabel='Manufacturer', ylabel='Engine_size'>

# %%
sns.set(rc={'figure.figsize':(25,8)})
sns.barplot(data['Manufacturer'],data['__year_resale_value'])
# Out:
# <AxesSubplot:xlabel='Manufacturer', ylabel='__year_resale_value'>

# %%
sns.set(rc={'figure.figsize':(25,8)})
sns.barplot(data['Manufacturer'],data['Price_in_thousands'])
# Out:
# <AxesSubplot:xlabel='Manufacturer', ylabel='Price_in_thousands'>

# %%
sns.set(rc={'figure.figsize':(25,8)})
sns.barplot(data['Manufacturer'],data['Width'])
# Out:
# <AxesSubplot:xlabel='Manufacturer', ylabel='Width'>

# %%
sns.set(rc={'figure.figsize':(25,8)})
sns.barplot(data['Manufacturer'],data['Horsepower'])
# Out:
# <AxesSubplot:xlabel='Manufacturer', ylabel='Horsepower'>

# %%
sns.set(rc={'figure.figsize':(25,8)})
sns.barplot(data['Manufacturer'],data['Wheelbase'])
# Out:
# <AxesSubplot:xlabel='Manufacturer', ylabel='Wheelbase'>

# %%
sns.set(rc={'figure.figsize':(25,8)})
sns.barplot(data['Manufacturer'],data['Length'])
# Out:
# <AxesSubplot:xlabel='Manufacturer', ylabel='Length'>

# %%
sns.set(rc={'figure.figsize':(25,8)})
sns.barplot(data['Manufacturer'],data['Fuel_efficiency'])
# Out:
# <AxesSubplot:xlabel='Manufacturer', ylabel='Fuel_efficiency'>

# %%
sns.set(rc={'figure.figsize':(25,8)})
sns.barplot(data['Manufacturer'],data['Curb_weight'])
# Out:
# <AxesSubplot:xlabel='Manufacturer', ylabel='Curb_weight'>

# %%
sns.distplot(data['Sales_in_thousands'])
# Out:
# <AxesSubplot:xlabel='Sales_in_thousands', ylabel='Density'>
